# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
#testt
bp1 = pd.DataFrame({
    "Employee_Name": ["Ramesh","Amesh","Mesh","Esh","Sh","H","Anish","Nish"], 
    "Salary" : [1000,2000,3000,4000,5000,6000,7000,8000]
})
plt.boxplot(bp1["Salary"])
plt.title("Employee Salary")
# Out:
# Text(0.5, 1.0, 'Employee Salary')

# %%
bp2 = pd.DataFrame({
    "Employee_Name": ["Ramesh","Amesh","Mesh","Esh","Sh","H","Anish","Nish","Outliername"], 
    "Salary" : [1000,2000,3000,4000,5000,6000,7000,8000,50000]
})
plt.boxplot(bp2["Salary"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x128ac747a10>,
#   <matplotlib.lines.Line2D at 0x128ac747b60>],
#  'caps': [<matplotlib.lines.Line2D at 0x128ac747cb0>,
#   <matplotlib.lines.Line2D at 0x128ac747e00>],
#  'boxes': [<matplotlib.lines.Line2D at 0x128ac7478c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x128ac8f8050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x128ac8f81a0>],
#  'means': []}

# %%
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x128ac2c41a0>,
#   <matplotlib.lines.Line2D at 0x128ac2c42f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x128ac2c4440>,
#   <matplotlib.lines.Line2D at 0x128ac2c4590>],
#  'boxes': [<matplotlib.lines.Line2D at 0x128ac2c4050>],
#  'medians': [<matplotlib.lines.Line2D at 0x128ac2c46e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x128ac2c4830>],
#  'means': []}

# %%
bp3 = pd.read_csv("datasets/daraz_dataset.csv")
plt.boxplot(bp3["UnitPrice"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x128acb47380>,
#   <matplotlib.lines.Line2D at 0x128acb474d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x128acb47620>,
#   <matplotlib.lines.Line2D at 0x128acb47770>],
#  'boxes': [<matplotlib.lines.Line2D at 0x128acb47230>],
#  'medians': [<matplotlib.lines.Line2D at 0x128acb478c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x128acb47a10>],
#  'means': []}
