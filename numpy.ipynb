# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Price" : [100,200,300]
})
print(type(df["Price"].values))
# Out:
# <class 'numpy.ndarray'>

# %%
countries = ["nepal","india",21,True]

# %%
import numpy as np

# %%
salary_array = np.array([1000,2000,3000])
print(salary_array.ndim)
print(salary_array.shape)
print(salary_array.size)
print(salary_array[-1])

data = np.array([
    [10,1000], 
    [20,2000],
    [30,3000], 
    [40,3000], 
    [50,3000], 
    [60,3000]
])
print(data[:,1])
print(data[0:3])
print(data[0,1])
print(data.ndim) 
print(data.shape)
print(data.size)

price = np.array([10,20,30,40.6])
print(price.dtype)

price2 = np.array([10.5,20.3,30.5])
print(price2.dtype)
# Out:
# 1
# (3,)
# 3
# 3000
# [1000 2000 3000 3000 3000 3000]
# [[  10 1000]
#  [  20 2000]
#  [  30 3000]]
# 1000
# 2
# (6, 2)
# 12
# float64
# float64

# %%
numbers = np.array([1,2,3,4,5])
# 10,10,10,10,10  [1,2,3,4,5] --> 1 * 10, 2* 10, 3* 10, 4*10, 5*10
results = numbers * 10
# results
results[(results > 30) & (results < 50)]
# print(results)

price = np.array([100,200,300])
quantity = np.array([2,4,6])
print(price.shape)
price * quantity
# Out:
# (3,)
# array([ 200,  800, 1800])

# %%
numbers = [1,2,3,4,5]
# output ---> [10,20,30,40,50]
results = []
for num in numbers:
    
    results.append(num*10)
print(results)
# Out:
# [10, 20, 30, 40, 50]

# %%
[]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 numbers = [10,20,30]
# ----> 2 numbers + 10
#
# TypeError: can only concatenate list (not "int") to list

# %%
arr = np.array([1,2,3,4,5,6])
# arr.shape
# arr.reshape(2,3)
arr.reshape(3,-1)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
arr2= np.array([
    [1,2,3],
    [4,5,6]
])
# arr2.shape
# arr2.reshape(1,6)
arr2.reshape(6)
# arr2.shape
# Out:
# array([1, 2, 3, 4, 5, 6])
